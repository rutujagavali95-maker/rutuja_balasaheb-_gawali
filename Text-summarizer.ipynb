# %%
# !pip install pydrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#                                               0.0/987.4 kB ? eta -:--:--
#                                               0.0/987.4 kB ? eta -:--:--
#                                               10.2/987.4 kB ? eta -:--:--
#      --                                      61.4/987.4 kB 1.1 MB/s eta 0:00:01
#      -----                                  143.4/987.4 kB 1.1 MB/s eta 0:00:01
#      -----                                  143.4/987.4 kB 1.1 MB/s eta 0:00:01
#      -----                                  143.4/987.4 kB 1.1 MB/s eta 0:00:01
#      -------                              194.6/987.4 kB 695.5 kB/s eta 0:00:02
#      ------------                         337.9/987.4 kB 999.0 kB/s eta 0:00:01
#      --------------------                   522.2/987.4 kB 1.4 MB/s eta 0:00:01
# ...

# %%
# !pip install -U nltk # To Upgrade NLTK to >3.5 for METEOR score
# Out:
# ERROR: Invalid requirement: '#'
#
# [notice] A new release of pip is available: 23.1.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

print('The nltk version is {}.'.format(nltk.__version__)) # Verify version >3.5
# Out:
# The nltk version is 3.9.4.

# %%
import numpy as np 
import pandas as pd

# %%
import os
print(os.listdir(r'C:\Users\Dell\Downloads'))
# Out:
# ['Anaconda3-2025.12-2-Windows-x86_64.exe', 'angular_lazy_loading_lab.docx', 'breast_cancer.csv', 'desktop.ini', 'Experiment No.1 (1).docx', 'Experiment No.1 (2).docx', 'Experiment No.1.docx', 'image.png', 'IMDB Dataset.txt', 'links.csv', 'MAD EX (1) (1).doc', 'MAD EX (1).doc', 'MAD EX.doc', 'mongodb-windows-x86_64-8.2.6-signed.msi', 'mosquitto-2.1.2-install-windows-x64.exe', 'movies.csv', 'movie_genres.csv', 'news_summary.csv', 'node_experiment5.docx', 'openssl-4.0.0', 'openssl-4.0.0.tar.gz', 'Polity lecture 2.pdf', 'Polity The making of the constitution.pdf', 'Postman Agent v0.4.87 (x64).exe', 'Project (1).docx', 'Project.docx', 'Python-3.11.11.tar.xz', 'python-3.11.4-amd64.exe', 'ratings.csv', 'RxJS_Angular_Lab.docx', 'SubmittedData.pdf', 'tags.csv', 'Time and Work (Railway-2026) Practice Set.pdf', 'Time and Work 5classnotes.pdf', 'Time and Work class - 2 classnotes (1).pdf.crdownload', 'Time and Work class - 2 classnotes.pdf', 'Time and Work class -1 classnotes (1).pdf.crdownload'
# ...

# %%
import pandas as pd

summary = pd.read_csv(r'C:\Users\Dell\Downloads\news_summary.csv', encoding='latin-1')

raw = pd.read_csv(r'C:\Users\Dell\Downloads\news_summary_more (1).csv', encoding='latin-1')

print(summary.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 summary = pd.read_csv(r'C:\Users\Dell\Downloads\news_summary.csv', encoding='latin-1')
#       5 # 👇 FIX HERE (example name)
# ----> 6 raw = pd.read_csv(r'C:\Users\Dell\Downloads\news_summary_more (1).csv', encoding='latin-1')
#       8 print(summary.head())
#
# ...

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Dell\Downloads\news_summary (1).csv', encoding='iso-8859-1')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(r'C:\Users\Dell\Downloads\news_summary (1).csv', encoding='iso-8859-1')
#       4 print(df.head())
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
